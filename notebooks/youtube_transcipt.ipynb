# %%
from langchain.docstore.document import Document
from youtube_transcript_api import YouTubeTranscriptApi as yta
from typing import List

def get_youtube_transcript(video_id: str) -> List[Document]:
    try:
        transcript = yta.get_transcript(video_id)
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

    transcript_list = []
    plain_transcript = ""
    for entry in transcript:
        text = entry['text']
        start = entry['start']
        duration = entry['duration']
        
        # Convert start time to HH:MM:SS format
        hours, remainder = divmod(start, 3600)
        minutes, seconds = divmod(remainder, 60)
        timestamp = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"
        
        plain_transcript += text + " "
        
        new_transcript = {"text": text, "start": start, "duration": duration, "timestamp": timestamp}
        transcript_list.append(new_transcript)
        
    return transcript_list, plain_transcript

# %%
from langchain.docstore.document import Document
from youtube_transcript_api import YouTubeTranscriptApi as yta
from typing import List

def get_youtube_transcript(video_id: str) -> List[Document]:
    try:
        transcript = yta.get_transcript(video_id)
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

    documents = []
    for entry in transcript:
        text = entry['text']
        start_time = entry['start']
        duration = entry['duration']
        
        # Convert start time to HH:MM:SS format
        hours, remainder = divmod(start_time, 3600)
        minutes, seconds = divmod(remainder, 60)
        timestamp = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"
        
        # Create a Document with the text and metadata
        doc = Document(
            page_content=text,
            metadata={
                "start_time": start_time,
                "duration": duration,
                "timestamp": timestamp
            }
        )
        documents.append(doc)

    return documents

# %%
video_id = "pxuXaaT1u3k"  # Replace with your YouTube video ID
transcript, plain_transcript = get_youtube_transcript(video_id)

print(plain_transcript)

for doc in transcript:
    print(f"[{doc['timestamp']}] {doc['text']}")
# Out:
# in this video I'm going to take a deep dive into Python's logging package now you might think logging I mean that's kind of boring should we really watch a video about that why is that important but in commercial software products vlogging is actually crucial because login allows to detect bugs sooner it allows to trace back easily when a problem occurs in your platform so you can better help your customers and it also helps you detect and deal with for example hacking attempts but in order to do all these things you need to make sure that logging is set up correctly so that you can actually benefit from it the most so today I'll talk about how to do that in Python using Python's login module as well as a couple of things that are dealing with logs easier especially in a production environment and finally I'm going to talk about one huge mistake with logging that many companies make but fortunately you can do something to avoid it next to the logging helping you finding bugs and problems in your code it's also really good to develop your skill of diagnosing code in general so I created a free workshop on code diagnosis that you can access via Prime book called slash diagnosis it's about half an hour of content where I dive into a three Factor framework to help you analyze code more effectively I'll show you how to apply that framework by looking at actual production code so Arnold codes diagnosis to get access for free I've also put the link in the description of this video now let's dive in so I'm going to start by just showing you a very basic example of logging in Python I'm importing the login package here as you see I have main function that does nothing but logging that's normally not what you have of course but this just shows the basic capabilities of the package what I'm doing here in the first step is supplying a very basic configuration of logging by in this case simply supplying the level which is the warning level and then I post a number of different log messages a debug message info warning an error and a critical message and what this level does is that it determines which level of logging you want to print so when I run this you see that I'm printing warning error and critical but the debug and info messages are not shown now if I also want to show for example info messages I change this to info and I want to run this again you see we get also the info logging message or if I really want to go low level and also show debug then I run this and then I also show the debug messages so these are the five levels of severity of logging debug info warning error and critical being able to control up until what level you want to print logs is actually really helpful because then throughout your application you can use these severity levels to print things and you only have one place where you're defining how detailed the logs should be and you don't have to go through your code and enable and disable log messages just because you don't want to show them you simply Define in your basic config which severity level you want to see just the critical errors or do you want to basically see everything including low level debugging messages you can even imagine that this level is something that you might want to be able to set from let's say a database so that even when your application is already deployed you can in principle change the database logging level and then that's going to change the way that your application logging happens so basic config has other arguments as well for example you can set the file name if you want to write logs to a file or you can change the way that logging is formatted and I'll show you an example of that here I have a slightly modified version of the example that adds some formatting to logging so in this case what I'm doing is that I format it according to the time and the name of the level and then the message and it also provide a string formatting how date and time should look like in the ...
# [00:00:00] in this video I'm going to take a deep
# [00:00:01] dive into Python's logging package now
# [00:00:04] you might think logging I mean that's
# [00:00:06] kind of boring should we really watch a
# [00:00:08] video about that why is that important
# [00:00:10] but in commercial software products
# [00:00:12] vlogging is actually crucial because
# [00:00:15] login allows to detect bugs sooner it
# [00:00:17] allows to trace back easily when a
# [00:00:19] problem occurs in your platform so you
# [00:00:21] can better help your customers and it
# [00:00:23] also helps you detect and deal with for
# [00:00:26] example hacking attempts but in order to
# [00:00:28] do all these things you need to make
# [00:00:30] sure that logging is set up correctly so
# [00:00:32] that you can actually benefit from it
# [00:00:34] the most so today I'll talk about how to
# [00:00:36] do that in Python using Python's login
# [00:00:38] module as well as a couple of things
# [00:00:40] that are dealing with logs easier
# [00:00:42] especially in a production environment
# [00:00:44] and finally I'm going to talk about one
# [00:00:47] huge mistake with logging that many
# [00:00:49] companies make but fortunately you can
# [00:00:52] do something to avoid it next to the
# [00:00:54] logging helping you finding bugs and
# [00:00:56] problems in your code it's also really
# [00:00:58] good to develop your skill of diagnosing
# [00:01:01] code in general so I created a free
# [00:01:04] workshop on code diagnosis that you can
# [00:01:06] access via Prime book called slash
# [00:01:08] diagnosis it's about half an hour of
# [00:01:10] content where I dive into a three Factor
# [00:01:13] framework to help you analyze code more
# [00:01:16] effectively I'll show you how to apply
# [00:01:18] that framework by looking at actual
# [00:01:20] production code so Arnold codes
# [00:01:22] diagnosis to get access for free I've
# [00:01:24] also put the link in the description of
# [00:01:26] this video now let's dive in so I'm
# [00:01:30] going to start by just showing you a
# [00:01:31] very basic example of logging in Python
# [00:01:33] I'm importing the login package here as
# [00:01:36] you see I have main function that does
# [00:01:38] nothing but logging that's normally not
# [00:01:39] what you have of course but this just
# [00:01:42] shows the basic capabilities of the
# [00:01:43] package what I'm doing here in the first
# [00:01:45] step is supplying a very basic
# [00:01:47] configuration of logging by in this case
# [00:01:49] simply supplying the level which is the
# [00:01:51] warning level and then I post a number
# [00:01:54] of different log messages a debug
# [00:01:57] message info warning an error and a
# [00:01:59] critical message and what this level
# [00:02:02] does is that it determines which level
# [00:02:04] of logging you want to print so when I
# [00:02:07] run this you see that I'm printing
# [00:02:09] warning error and critical but the debug
# [00:02:12] and info messages are not shown
# [00:02:15] now if I also want to show for example
# [00:02:17] info messages
# [00:02:19] I change this to info and I want to run
# [00:02:21] this again you see we get also the info
# [00:02:23] logging message or if I really want to
# [00:02:26] go low level and also show debug then I
# [00:02:29] run this and then I also show the debug
# [00:02:32] messages so these are the five levels of
# [00:02:34] severity of logging debug info warning
# [00:02:36] error and critical being able to control
# [00:02:38] up until what level you want to print
# [00:02:41] logs is actually really helpful because
# [00:02:43] then throughout your application you can
# [00:02:45] use these severity levels to print
# [00:02:48] things and you only have one place where
# [00:02:51] you're defining how detailed the logs
# [00:02:54] should be and you don't have to go
# [00:02:55] through your code and enable and disable
# [00:02:58] log messages just because you don't want
# [00:03:00] to show them you simply Define in your
# [00:03:02] basic config which severity level you
# [00:03:05] want to see just the critical errors or
# [00:03:07] do you want to basically see everything
# [00:03:08] including low level debugging messages
# [00:03:11] you can even imagine that this level is
# [00:03:14] something that you might want to be able
# [00:03:15] to set from let's say a database so that
# [00:03:18] even when your application is already
# [00:03:20] deployed you can in principle change the
# [00:03:23] database logging level and then that's
# [00:03:26] going to change the way that your
# [00:03:28] application logging happens so basic
# [00:03:30] config has other arguments as well for
# [00:03:32] example you can set the file name if you
# [00:03:33] want to write logs to a file or you can
# [00:03:36] change the way that logging is formatted
# [00:03:38] and I'll show you an example of that
# [00:03:39] here I have a slightly modified version
# [00:03:42] of the example that adds some formatting
# [00:03:44] to logging so in this case what I'm
# [00:03:46] doing is that I format it according to
# [00:03:49] the time and the name of the level and
# [00:03:52] then the message and it also provide a
# [00:03:54] string formatting how date and time
# [00:03:57] should look like in these log messages
# [00:03:59] so before we simply add this we had the
# [00:04:02] level and root which is the root logging
# [00:04:06] application and the message but now when
# [00:04:07] I run this with formatting it's going to
# [00:04:09] look slightly differently so you see we
# [00:04:11] have the date and the time here we have
# [00:04:14] the level and there is a space between
# [00:04:15] each of these things and then we get the
# [00:04:18] actual message so this type of
# [00:04:19] formatting is really helpful really easy
# [00:04:21] to change and then you change it again
# [00:04:24] in one place and then it's applied
# [00:04:25] everywhere throughout your application
# [00:04:27] code default login writes the logs to
# [00:04:29] the console but you might also want to
# [00:04:31] write a to file and you can simply do
# [00:04:33] that by adding a file name argument in
# [00:04:35] this case basic.box so when I run this
# [00:04:37] we see that we don't get basic console
# [00:04:40] logs anymore but if I open the file
# [00:04:43] browser you see that there's now basic
# [00:04:45] DOT log file that contains the logs that
# [00:04:47] were generated and logging adds to the
# [00:04:49] existing log file so if I run the log
# [00:04:52] again then you see that base.log now
# [00:04:54] contains these logs twice so this is a
# [00:04:56] great way to keep track of what happened
# [00:04:58] in earlier runs of your application it's
# [00:05:00] really easy to set up by the way if
# [00:05:02] you're enjoying this video so far give
# [00:05:04] the like it really helps other people
# [00:05:05] find my content on YouTube now simply
# [00:05:08] writing a log to console or file is fine
# [00:05:10] but if you're developing more complex
# [00:05:12] application you generally want to have
# [00:05:14] more control over how logging happens
# [00:05:16] and it can be helpful to use a logging
# [00:05:19] surface what log surfaces do is that
# [00:05:21] they give you an easier way to visualize
# [00:05:23] logs search logs have overall more
# [00:05:26] control over how long logs are being
# [00:05:28] saved and backups and things like that
# [00:05:30] and they also are helpful sometimes if
# [00:05:34] you want to give somebody else in your
# [00:05:35] team maybe somebody is not a developer
# [00:05:37] access to the logs because that might
# [00:05:39] sometimes be useful there are several
# [00:05:41] companies that offer logging surfaces
# [00:05:43] I'm going to show you one of them today
# [00:05:45] that's paper trail they're not
# [00:05:47] sponsoring this video or anything I
# [00:05:48] simply use them in the past and I
# [00:05:50] thought it might be nice to just give
# [00:05:51] you an example of what that looks like
# [00:05:52] it's actually really easy to integrate
# [00:05:54] in Python here I have a very simple
# [00:05:57] setup of how that works so the only
# [00:05:59] thing you need to do is you supply a
# [00:06:02] host and a port that basically tells the
# [00:06:04] logging system
# [00:06:05] where to send the logs to by the way by
# [00:06:08] the time you're watching this video this
# [00:06:10] account no longer exists still sending
# [00:06:11] logs to this account really doesn't do
# [00:06:13] anything but you have your main function
# [00:06:16] where I now use the logging module to
# [00:06:18] create a locker object and that's
# [00:06:20] basically what you're seeing here so in
# [00:06:22] my previous example I simply used
# [00:06:24] login.basic config but what I'm doing
# [00:06:27] here is that I have a logger object and
# [00:06:30] then I can also give that a name so you
# [00:06:32] can have different logger objects for
# [00:06:34] different parts of your application for
# [00:06:36] example you could make one for your
# [00:06:38] backhand you could make another one for
# [00:06:40] your front end or you could even split
# [00:06:41] it up more if you wanted to and the name
# [00:06:43] of the application can also be mentioned
# [00:06:45] in your log so you can easily find back
# [00:06:47] where each log message came from very
# [00:06:49] similar like we did with basic config
# [00:06:51] your logger also has things like setting
# [00:06:54] a logging level and in order to be able
# [00:06:55] to send logs to a surface like paper
# [00:06:59] trail well you need to add a Handler
# [00:07:02] and that's what I'm doing here the basic
# [00:07:04] Handler you can use for this is the
# [00:07:06] syslog Handler that gets an address that
# [00:07:09] is the host on the board and then we
# [00:07:11] simply add this Handler to the logger
# [00:07:13] and you can add multiple handlers so if
# [00:07:15] you want to have the log being sent to
# [00:07:17] Paper Trail but you also want it saved
# [00:07:19] to a file you simply add a file Handler
# [00:07:21] here and then we send a debug message so
# [00:07:24] let me run this and now it has sent the
# [00:07:27] login message to the logging surface so
# [00:07:30] normally these login Services they give
# [00:07:31] you access to web-based interface where
# [00:07:33] you can browse search these logs for
# [00:07:36] paper trail this is basically what it
# [00:07:38] looks like and we see our login message
# [00:07:40] right here that's the model logo matches
# [00:07:42] as well I was trying out a few things
# [00:07:43] but here you see our debug message and
# [00:07:46] you also see that this comes from the
# [00:07:48] logger and what's nice is that paper
# [00:07:49] trail basically stores the logs for you
# [00:07:52] keeps them available for a number of
# [00:07:54] days so you can still browse them for a
# [00:07:56] while if you want to look for a problem
# [00:07:57] and they offer some possibilities to
# [00:08:00] search for logs for example if I search
# [00:08:01] for
# [00:08:02] debug then I'm simply going to find this
# [00:08:05] message that was sent a few minutes ago
# [00:08:07] so that's really helpful and they have a
# [00:08:09] couple of other things like there's
# [00:08:11] charts that show you things like how
# [00:08:13] many logs are being generated you have a
# [00:08:15] couple of different settings about what
# [00:08:17] you want to show or hide you can store
# [00:08:19] favorite searches so you can quickly
# [00:08:21] find things like I want to see quickly
# [00:08:23] all the authentication errors or all the
# [00:08:25] field login attempts or whatever so for
# [00:08:28] those kind of things having a logging
# [00:08:30] service like paper trail is really
# [00:08:31] helpful and then of course you can give
# [00:08:33] access to other members of your team to
# [00:08:35] Paper Trail so they can easily see
# [00:08:37] what's going on in the system without
# [00:08:39] having to actually log into your server
# [00:08:41] if you have any thoughts about logging
# [00:08:43] services like paper trail or you have
# [00:08:45] some experience with them just post it
# [00:08:47] in a comment and let me know if you have
# [00:08:48] any tips there's one big mistake that
# [00:08:51] companies make when they're dealing with
# [00:08:52] logs and that is that they often forget
# [00:08:55] that they're logging things and as a
# [00:08:57] result logs are actually a common reason
# [00:09:00] for data leaks for example Twitter had
# [00:09:02] data league in 2018 due to unhashed
# [00:09:06] passwords being stored in a log file or
# [00:09:08] the Cam4 streaming site they locked
# [00:09:11] events in elastic search and basically
# [00:09:13] the database was openly accessible and
# [00:09:15] included email addresses Etc so not
# [00:09:18] treating logs and logging seriously is
# [00:09:21] really dangerous so how do you address
# [00:09:23] this well one is that you always need to
# [00:09:25] assume that your logs and log files are
# [00:09:28] not secure and that potentially they're
# [00:09:30] going to be open to everybody so you
# [00:09:32] need to make sure that you're never
# [00:09:33] sending any sensitive information to
# [00:09:36] logs so don't send email addresses don't
# [00:09:39] lock passwords just don't do don't look
# [00:09:42] credit card information just don't do
# [00:09:44] that kind of stuff because logs are
# [00:09:46] potentially open and you can't trust
# [00:09:48] that they won't ever be seen by anybody
# [00:09:51] else but your own development team also
# [00:09:53] make sure that as a software development
# [00:09:55] you have a grasp on where log data is
# [00:09:58] sent to and how it's being stored and
# [00:10:00] also make sure they have clear how long
# [00:10:02] that law log data is being saved and
# [00:10:04] when it should be deleted and make sure
# [00:10:07] that it actually happens that it's
# [00:10:08] actually being deleted and for that
# [00:10:09] reason it's actually pretty smart to use
# [00:10:11] a locking surface because they're
# [00:10:13] supposed to be good at that stuff and
# [00:10:15] they're supposed to manage that stuff
# [00:10:16] properly for you even though logging
# [00:10:18] Services can still make mistakes and
# [00:10:20] have data leaks themselves that's why my
# [00:10:23] first point is so important never assume
# [00:10:25] that your log files are secure and
# [00:10:27] simply don't store any sensitive data in
# [00:10:29] logs if you do store things yourself
# [00:10:31] whether that's in a log file or a
# [00:10:33] database just make sure your team treats
# [00:10:35] logs seriously it potentially contains
# [00:10:38] sensitive information that's for
# [00:10:39] internal use only and you want to be
# [00:10:42] careful with that knowing how to set up
# [00:10:44] logging properly is just part of how you
# [00:10:46] can make building and maintaining
# [00:10:47] software products more manageable I did
# [00:10:50] a video a while ago about some other
# [00:10:52] aspects that you should probably think
# [00:10:54] about as well you can watch that next if
# [00:10:56] you'd like thanks for watching take care
# [00:10:59] and see you next week

# %% [markdown]
# # YT Metadata

# %%
from pytube import YouTube

def scrap_youtube_metadata(youtube_id: str):
    yt = YouTube(f"https://www.youtube.com/watch?v={youtube_id}")
    return {
        "title": yt.title,
        "author": yt.author,
        "description": yt.description,
    }

# %%
scrap_youtube_metadata("pxuXaaT1u3k")
# Out:
# {'title': 'Python Logging: How to Write Logs Like a Pro!',
#  'author': 'ArjanCodes',
#  'description': None}

# %%
from pytube import YouTube

yt = YouTube('http://youtube.com/watch?v=2lAe1cqCOXo')

yt.title
# Out:
# 'YouTube Rewind 2019: For the Record | #YouTubeRewind'

# %%
yt.author
# Out:
# 'YouTube'

# %%
yt.description
